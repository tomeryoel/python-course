# %% [markdown]
# <h1>QUESTION1</H1>
# <B>Momi - Tomer </b>
# <br/>
# <span style="color: red">Shimoni</span>

# %% [markdown]
# <h2>QUESTION2</H2>
# <B>0524722207</B>
# <br/>
# <b><i>Rosh Haayin</i></b>

# %% [markdown]
# ### QUESTION3
# The pyramid
#
#       |
#           |
#               |
#                   |
#                       |

# %% [markdown]
# <h3>QUESTION4</H3>
#
#
# $a^2 + b^2 = c^2$

# %%
# QUESTION5
x = 3
y = 3.141
AREA = y * x ** 2
print(x, y , AREA)
print(type(x), type(y), type(AREA))
# Out:
# 3 3.141 28.269
# <class 'int'> <class 'float'> <class 'float'>

# %%
# QUESTION6

print(AREA // 4 <= 7)
print(AREA / 4 < 7)
print(not AREA / 4 < 7 and AREA // 4 <= 7)
# Out:
# True
# False
# True

# %%
# QUESTION7

str_name = "Tomer Shimoni"
print(str_name[0::2])
print(str_name[1::2])
# Out:
# TmrSioi
# oe hmn

# %%
# QUESTION8

a ="#####"
b ="*****"
c = "Tomer Shimoni"
print(a + c + b)

space_index = c.find(" ")

first_name_len = space_index
last_name_len = len(c) - space_index - 1

print(f"First name length: {first_name_len}")
print(f"Last name length: {last_name_len}")
# Out:
# #####Tomer Shimoni*****
# First name length: 5
# Last name length: 7

# %%
# QUESTION9

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

circle1 = plt.Circle((1, 1), 0.5, color="red")
circle2 = plt.Circle((2, 1), 0.5, color="red")

ax.add_patch(circle1)
ax.add_patch(circle2)

ax.set_aspect("equal")

plt.xlim(0.9, 2.1)
plt.ylim(0.5, 1.5)

plt.show()
